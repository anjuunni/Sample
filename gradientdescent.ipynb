# %% [markdown]
# <a href="https://colab.research.google.com/github/anjuunni/Sample/blob/main/gradientdescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def gradient_descent(x,y):
    m_curr=b_curr=0
    iterations=10000
    n=len(x)
    learning_rate=0.000001
    for i in range(iterations):
        y_predicted=m_curr * x + b_curr
        cost=(1/n) * sum([val**2 for val in (y-y_predicted)])
        md=-(2/n)*sum(x*(y-y_predicted))
        bd=-(2/n)*sum(y-y_predicted)
        m_curr=m_curr-learning_rate*md
        b_curr=b_curr-learning_rate*bd
        print("m {}, b {},cost {} , iteration {}".format(m_curr,b_curr,cost,i))

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 2.000000000000001, b 2.9999999999999947,cost 1.0255191767873153e-29 , iteration 5000
# m 2.000000000000002, b 2.999999999999995,cost 1.0255191767873153e-29 , iteration 5001
# m 2.000000000000001, b 2.9999999999999947,cost 1.0255191767873153e-29 , iteration 5002
# m 2.000000000000002, b 2.999999999999995,cost 1.0255191767873153e-29 , iteration 5003
# m 2.000000000000001, b 2.9999999999999947,cost 1.0255191767873153e-29 , iteration 5004
# m 2.000000000000002, b 2.999999999999995,cost 1.0255191767873153e-29 , iteration 5005
# m 2.000000000000001, b 2.9999999999999947,cost 1.0255191767873153e-29 , iteration 5006
# m 2.000000000000002, b 2.999999999999995,cost 1.0255191767873153e-29 , iteration 5007
# m 2.000000000000001, b 2.9999999999999947,cost 1.0255191767873153e-29 , iteration 5008
# m 2.000000000000002, b 2.999999999999995,cost 1.0255191767873153e-29 , iteration 5009
# ...

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-44b86bd7-7cb6-46f4-b137-fa72bd3f2d8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44b86bd7-7cb6-46f4-b137-fa72bd3f2d8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_scores.csv to test_scores.csv

# %%
test_scores=pd.read_csv("test_scores.csv")

# %%
test_scores
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
math=test_scores['math'].to_list()
math_test=np.array(math)
math_test
# Out:
# array([92, 56, 88, 70, 80, 49, 65, 35, 66, 67])

# %%
cs=test_scores['cs'].to_list()
cs_test=np.array(cs)
cs_test
# Out:
# array([98, 68, 81, 80, 83, 52, 66, 30, 68, 73])

# %%
gradient_descent(math_test,cs_test)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 1.044538250762771, b 0.01583022723170194,cost 31.811613793009215 , iteration 5000
# m 1.0445382476861909, b 0.015830445260945573,cost 31.811613745462996 , iteration 5001
# m 1.0445382446096112, b 0.015830663290164176,cost 31.81161369791677 , iteration 5002
# m 1.0445382415330318, b 0.01583088131935775,cost 31.811613650370568 , iteration 5003
# m 1.0445382384564528, b 0.0158310993485263,cost 31.811613602824373 , iteration 5004
# m 1.044538235379874, b 0.01583131737766982,cost 31.811613555278196 , iteration 5005
# m 1.0445382323032957, b 0.015831535406788312,cost 31.811613507732012 , iteration 5006
# m 1.0445382292267178, b 0.01583175343588178,cost 31.811613460185892 , iteration 5007
# m 1.0445382261501401, b 0.015831971464950217,cost 31.811613412639744 , iteration 5008
# m 1.044538223073563, b 0.015832189493993627,cost 31.811613365093592 , iteration 5009
# ...
