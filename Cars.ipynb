# %% [markdown]
# <a href="https://colab.research.google.com/github/anjuunni/Sample/blob/main/Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-020350b9-51f8-4e8f-ac0a-b7757321ece8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-020350b9-51f8-4e8f-ac0a-b7757321ece8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mpg.csv to mpg.csv

# %%
mpg=pd.read_csv('mpg.csv')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  ...  model_year  origin                       name
# 0  18.0          8         307.0  ...          70     usa  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...          70     usa          buick skylark 320
# 2  18.0          8         318.0  ...          70     usa         plymouth satellite
# 3  16.0          8         304.0  ...          70     usa              amc rebel sst
# 4  17.0          8         302.0  ...          70     usa                ford torino
#
# [5 rows x 9 columns]

# %%
car_name=mpg.name.str.split(' ')

# %%
def Extract(lst): 
    return [item[0] for item in lst]

# %%
Extract(car_name)
# Out:
# ['chevrolet',
#  'buick',
#  'plymouth',
#  'amc',
#  'ford',
#  'ford',
#  'chevrolet',
#  'plymouth',
#  'pontiac',
#  'amc',
#  'dodge',
#  'plymouth',
#  'chevrolet',
#  'buick',
#  'toyota',
#  'plymouth',
#  'amc',
#  'ford',
#  'datsun',
#  'volkswagen',
#  'peugeot',
#  'audi',
#  'saab',
#  'bmw',
#  'amc',
#  'ford',
#  'chevy',
#  'dodge',
#  'hi',
#  'datsun',
#  'chevrolet',
#  'toyota',
#  'ford',
#  'amc',
#  'plymouth',
#  'chevrolet',
#  'ford',
#  'amc',
#  'chevrolet',
#  'pontiac',
#  'ford',
#  'plymouth',
#  'dodge',
#  'ford',
#  'pontiac',
#  'amc',
#  'chevrolet',
#  'pontiac',
#  'ford',
#  'mercury',
#  'opel',
#  'peugeot',
#  'fiat',
#  'toyota',
#  'datsun',
#  'volkswagen',
#  'plymouth',
#  'toyota',
#  'dodge',
#  'volkswagen',
#  'chevrolet',
#  'ford',
#  'chevrolet',
#  'pontiac',
#  'plymouth',
#  'ford',
#  'amc',
#  'mercury',
#  'buick',
#  'oldsmobile',
#  'chrysler',
#  'mazda',
#  'amc',
#  'chevrolet',
#  'ford',
#  'plymouth',
#  'volvo',
# ...

# %%
mpg_value=mpg['mpg']

# %%
mpg_value
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
conditions = [
    (mpg['mpg'] <= 17),
    (mpg['mpg'] > 17) & (mpg['mpg'] <= 29),
    (mpg['mpg'] > 29)
    ]

# %%
values = ['Low','Medium','High']

# %%
mpg['mpg_level'] = np.select(conditions, values)

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  ...  origin                       name  mpg_level
# 0  18.0          8         307.0  ...     usa  chevrolet chevelle malibu     Medium
# 1  15.0          8         350.0  ...     usa          buick skylark 320        Low
# 2  18.0          8         318.0  ...     usa         plymouth satellite     Medium
# 3  16.0          8         304.0  ...     usa              amc rebel sst        Low
# 4  17.0          8         302.0  ...     usa                ford torino        Low
#
# [5 rows x 10 columns]

# %%
mpg.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# mpg_level       False
# dtype: bool

# %%
mpg.dropna(axis=0,how='any',inplace=True)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
#  9   mpg_level     392 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 33.7+ KB

# %%
mpg.describe()
# Out:
#               mpg   cylinders  ...  acceleration  model_year
# count  392.000000  392.000000  ...    392.000000  392.000000
# mean    23.445918    5.471939  ...     15.541327   75.979592
# std      7.805007    1.705783  ...      2.758864    3.683737
# min      9.000000    3.000000  ...      8.000000   70.000000
# 25%     17.000000    4.000000  ...     13.775000   73.000000
# 50%     22.750000    4.000000  ...     15.500000   76.000000
# 75%     29.000000    8.000000  ...     17.025000   79.000000
# max     46.600000    8.000000  ...     24.800000   82.000000
#
# [8 rows x 7 columns]

# %%
mpg['origin'].value_counts()
# Out:
# usa       245
# japan      79
# europe     68
# Name: origin, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(mpg['horsepower'],mpg['mpg'])
plt.ylabel('mpg')
plt.xlabel('horsepower')
plt.title('Relationship between horsepower and mpg')
# Out:
# Text(0.5, 1.0, 'Relationship between horsepower and mpg')

# %%
import seaborn as sns

# %%
sns.scatterplot(mpg['horsepower'],mpg['mpg'],mpg['origin'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
g = sns.FacetGrid(mpg, col="origin")
g.map(sns.regplot, "horsepower", "mpg")
g.add_legend()

# %%
g = sns.FacetGrid(mpg, col="mpg_level", hue="origin")
g.map(sns.scatterplot, "horsepower", "mpg", alpha=.7)
g.add_legend()

# %%
plt.hist(mpg['mpg'],bins=30)
# Out:
# (array([ 3.,  4.,  6., 39., 17., 22., 16., 36., 21., 18., 14., 26., 15.,
#         21., 17., 22., 12., 14., 16., 11., 10., 10.,  6.,  6.,  2.,  2.,
#          0.,  3.,  2.,  1.]),
#  array([ 9.        , 10.25333333, 11.50666667, 12.76      , 14.01333333,
#         15.26666667, 16.52      , 17.77333333, 19.02666667, 20.28      ,
#         21.53333333, 22.78666667, 24.04      , 25.29333333, 26.54666667,
#         27.8       , 29.05333333, 30.30666667, 31.56      , 32.81333333,
#         34.06666667, 35.32      , 36.57333333, 37.82666667, 39.08      ,
#         40.33333333, 41.58666667, 42.84      , 44.09333333, 45.34666667,
#         46.6       ]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(mpg['horsepower'],bins=30)
# Out:
# (array([10.,  5., 12., 44., 32., 19., 45., 44., 31., 15., 23.,  6.,  8.,
#          7.,  4., 11., 31.,  5.,  3.,  5.,  5., 10.,  0.,  4.,  2.,  1.,
#          2.,  3.,  1.,  4.]),
#  array([ 46.        ,  52.13333333,  58.26666667,  64.4       ,
#          70.53333333,  76.66666667,  82.8       ,  88.93333333,
#          95.06666667, 101.2       , 107.33333333, 113.46666667,
#         119.6       , 125.73333333, 131.86666667, 138.        ,
#         144.13333333, 150.26666667, 156.4       , 162.53333333,
#         168.66666667, 174.8       , 180.93333333, 187.06666667,
#         193.2       , 199.33333333, 205.46666667, 211.6       ,
#         217.73333333, 223.86666667, 230.        ]),
#  <a list of 30 Patch objects>)

# %%
g = sns.FacetGrid(mpg, col="cylinders", hue="origin")
g.map(sns.scatterplot, "mpg", "displacement", alpha=.7)
g.add_legend()

# %%
mpg['model_year'].value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 82    30
# 75    30
# 79    29
# 70    29
# 81    28
# 77    28
# 72    28
# 80    27
# 71    27
# 74    26
# Name: model_year, dtype: int64

# %%
ax = sns.lineplot(data=mpg, x="model_year", y="mpg",err_style="bars")
ax.set(xticks=mpg['model_year'])
figsize = (30, 90)
#sns.lineplot(
#    data=fmri, x="timepoint", y="signal", hue="event", err_style="bars", ci=68
#)
#g=sns.lineplot(mpg['model_year'],mpg['mpg'])

#g.set(xticklabels=['1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982'])

# %%
g = sns.FacetGrid(mpg, col="origin")
g.map(sns.lineplot, "model_year", "mpg")
g.set(xticks=mpg['model_year'])
g.add_legend()

# %%
mpg.groupby('origin')['cylinders'].mean()
# Out:
# origin
# europe    4.161765
# japan     4.101266
# usa       6.277551
# Name: cylinders, dtype: float64

# %%
sns.pairplot(
    mpg,
    x_vars=["mpg", "horsepower", "weight","acceleration"],
    y_vars=["mpg", "horsepower", "weight","acceleration"],hue="origin"
)

# %%
sns.pairplot(
    mpg,
    x_vars=["mpg", "horsepower"],
    y_vars=["mpg", "horsepower"]
)

# %%
sns.regplot(mpg['mpg'],mpg['horsepower'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot('mpg','horsepower',mpg,order=3)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import numpy as np

# %%
np.polyfit(mpg.mpg,mpg.horsepower,3)
# Out:
# array([-8.50566252e-03,  8.66793237e-01, -3.01312437e+01,  4.29581461e+02])

# %%
sns.regplot('mpg','weight',mpg)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot('mpg','weight',mpg,order=3)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
np.polyfit(mpg.mpg,mpg.weight,3)
# Out:
# array([-5.11798536e-02,  8.10886166e+00, -3.94714882e+02,  8.17119624e+03])

# %%
sns.regplot('mpg','displacement',mpg)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot('mpg','displacement',mpg,order=4)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
np.polyfit(mpg.mpg,mpg.displacement,4)
# Out:
# array([-1.85020736e-03,  1.94142006e-01, -6.63978907e+00,  7.21690403e+01,
#         1.66182553e+02])

# %%
 from sklearn.linear_model import LinearRegression
 import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.model_selection import train_test_split
Y=mpg['mpg']
X=mpg[['cylinders','displacement','weight','horsepower','acceleration','model_year']]
X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.3, random_state=0)

# %%
clf = LinearRegression()

# %%
model=clf.fit(X_train,Y_train)

predictions = model.predict(X_test)

# %%
from scipy import stats

# %%
result = sm.OLS( Y_train, X_train ).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.981
# Model:                            OLS   Adj. R-squared (uncentered):              0.980
# Method:                 Least Squares   F-statistic:                              2268.
# Date:                Wed, 03 Feb 2021   Prob (F-statistic):                   1.84e-226
# Time:                        14:35:12   Log-Likelihood:                         -723.78
# No. Observations:                 274   AIC:                                      1460.
# Df Residuals:                     268   BIC:                                      1481.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
